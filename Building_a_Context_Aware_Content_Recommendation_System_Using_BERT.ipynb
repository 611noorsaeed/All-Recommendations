# %% [markdown]
# # Building a Context-Aware Content Recommendation System Using BERT Embeddings | News Articles Recommedations Using Sentence Transformers

# %% [markdown]
# # Step 1: Import Required Libraries

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # Step 2: Load Your Dataset

# %%
# Try reading the file with a different encoding
df = pd.read_csv('/content/Articles.csv', encoding='ISO-8859-1')

# Inspect the data
df
# Out:
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  strong>DUBAI: Dubai International Airport and ...  3/25/2017
# 2688  strong>BEIJING: Former Prime Minister, Shaukat...  3/26/2017
# 2689  strong>WASHINGTON: Uber has grounded its fleet...  3/26/2017
# 2690  strong>BEIJING: The New Development Bank plans...  3/27/2017
# 2691  strong>KARACHI: Karachi-based technology incub...  3/27/2017
#
#                                                 Heading  NewsType
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
# [2692 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Article     0
# Date        0
# Heading     0
# NewsType    0
# dtype: int64

# %% [markdown]
# # Step 3: Preprocessing the Text Data

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import re

# Download stopwords and punkt (for tokenization)
nltk.download('stopwords')
nltk.download('punkt')


# Initialize the PorterStemmer and stopwords
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()

# Preprocessing function to clean text (removes punctuation, converts to lowercase, removes stopwords, applies stemming)
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenize the text
    words = text.split()

    # Remove stopwords and apply stemming
    processed_words = [stemmer.stem(word) for word in words if word not in stop_words]

    # Join the words back into a string
    return " ".join(processed_words)

# Apply preprocessing to the 'Heading' column (or any other text column you want)
df['cleaned_heading'] = df['Heading'].apply(preprocess_text)

df
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  strong>DUBAI: Dubai International Airport and ...  3/25/2017
# 2688  strong>BEIJING: Former Prime Minister, Shaukat...  3/26/2017
# 2689  strong>WASHINGTON: Uber has grounded its fleet...  3/26/2017
# 2690  strong>BEIJING: The New Development Bank plans...  3/27/2017
# 2691  strong>KARACHI: Karachi-based technology incub...  3/27/2017
#
#                                                 Heading  NewsType  \
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
#                                         cleaned_heading
# 0     sindh govt decid cut public transport fare 7pc...
# 1                              asia stock new year trad
# 2                hong kong stock open 066 percent lower
# 3                  asian stock sink euro near nine year
# 4                             us oil price slip 50 barr
# ...                                                 ...
# 2687            laptop ban hit dubai 11m weekend travel
# 2688         pak china relat third countri shaukat aziz
# 2689                   uber ground self drive car accid
# 2690  new develop bank plan joint invest economi alo...
# 2691  googl power startup weekend energ proud pakist...
#
# [2692 rows x 5 columns]

# %% [markdown]
# # Step 4: Initialize The Sentence Transformer Model

# %%
# Load the pre-trained Sentence Transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')  # You can use other models if you prefer
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Step 5: Text Embeddings Using BERT

# %%
# Generate embeddings for all article headings in the dataset
headings = df['cleaned_heading'].tolist()  # Assuming you have a 'cleaned_heading' column
embeddings = model.encode(headings, convert_to_tensor=True)

# %%
embeddings
# Out:
# tensor([[-0.0313,  0.0338, -0.0093,  ..., -0.0394,  0.0069,  0.0495],
#         [-0.0520,  0.0016, -0.0221,  ..., -0.1266, -0.0875,  0.0417],
#         [ 0.0940, -0.0362,  0.0582,  ..., -0.1183, -0.0391,  0.0702],
#         ...,
#         [ 0.0069, -0.0256,  0.0097,  ...,  0.0711,  0.0768, -0.0734],
#         [ 0.0464, -0.0076, -0.0285,  ..., -0.1167,  0.0468, -0.0332],
#         [-0.1320,  0.1207,  0.0169,  ..., -0.0530, -0.0112, -0.0319]])

# %%
embeddings[0]
# Out:
# tensor([-3.1311e-02,  3.3842e-02, -9.3314e-03,  5.3722e-02, -4.4769e-02,
#          8.9522e-03,  4.7104e-02, -7.4335e-03, -3.6179e-02,  6.6231e-02,
#          2.2116e-02, -6.3882e-02,  1.2157e-02,  2.7805e-02, -1.8594e-02,
#         -8.3610e-02,  1.6920e-02,  6.8192e-02, -5.9756e-03, -2.9542e-02,
#          6.6594e-02,  3.6769e-02, -8.0550e-03,  4.9943e-02, -3.9254e-02,
#          8.4563e-03,  5.9706e-02,  1.1833e-02,  2.0560e-02, -3.3311e-02,
#         -8.6875e-03, -4.0942e-03, -1.0762e-02,  6.0253e-03, -1.1994e-05,
#          4.8461e-02,  3.7607e-03, -7.1833e-02,  4.2102e-02, -2.7863e-02,
#          4.5894e-02,  1.4585e-02, -6.1159e-02,  4.9844e-02,  9.6326e-02,
#         -2.9634e-02, -2.6796e-02,  4.3725e-02,  2.0296e-02, -2.0286e-02,
#          2.3837e-02,  1.1002e-01, -7.6997e-02,  5.1552e-02, -9.5125e-03,
#         -1.0269e-01, -4.3023e-02,  1.2116e-02,  1.5209e-02,  4.2475e-02,
#         -3.3582e-02, -4.3263e-03,  4.2477e-03, -6.0966e-02,  6.2552e-02,
#          8.9488e-03, -5.8474e-02, -9.1306e-02,  5.0694e-02, -4.1359e-02,
#          1.3653e-02, -1.4404e-02, -9.2196e-04, -1.3957e-02, -5.4714e-02,
#         -4.3097e-02, -3.5149e-02,  2.4764e-02, -6.8049e-02, -4.5914e-03,
#          9.9196e-03, -8.3741e-02, -5.2950e-02,  3.4034e-02,  1.5826e-02,
#         -5.0346e-02, -2.3180e-02, -3.3665e-02, -6.6395e-02,  1.0001e-02,
#          1.3789e-01,  2.7717e-02,  6.3366e-02,  3.0120e-02, -2.8482e-02,
#         -3.6196e-02, -4.8444e-02,  3.5748e-03,  1.4128e-02,  4.4520e-02,
#         -6.3270e-02,  9.4210e-02, -9.1606e-02,  1.0447e-01, -1.1378e-01,
#         -1.6894e-02,  2.7500e-02,  1.8685e-02, -5.1425e-02, -1.7095e-03,
#         -4.6519e-02,  6.1818e-02, -2.6702e-02, -4.6485e-02, -4.4413e-02,
#          4.6086e-02, -5.9225e-04,  1.0808e-03,  3.7536e-03, -5.3528e-03,
#         -1.0972e-01,  4.8485e-02, -1.9009e-02, -9.1897e-03, -1.5876e-02,
#          7.3791e-03,  4.5824e-02,  6.0540e-33, -1.2258e-01,  3.7856e-03,
#          3.0097e-02, -7.8143e-02, -2.4476e-03,  1.9715e-02, -1.1263e-01,
#          2.4787e-02,  2.3526e-02, -8.9434e-03,  1.7683e-02, -5.8753e-02,
#          7.6585e-02, -7.8215e-02,  6.0423e-02, -1.5919e-01,  7.9538e-03,
#          2.9036e-02,  4.8903e-02,  1.1107e-02, -1.7879e-03, -3.2174e-02,
#          1.5032e-02, -2.5881e-02,  4.3870e-02,  3.7793e-02, -3.8883e-02,
#          2.0862e-02,  7.6872e-02,  4.8970e-02,  6.4338e-03,  2.1271e-02,
#          6.0467e-03, -6.2191e-03, -5.3059e-02, -2.6619e-02, -4.7539e-02,
#         -2.3393e-03, -6.0594e-02, -2.3090e-02, -3.0528e-02, -3.3648e-02,
#         -3.7706e-02,  3.4348e-02, -7.4706e-02, -1.3123e-02,  6.5357e-02,
#          4.1369e-02,  5.2220e-03, -2.0925e-03,  2.7192e-02,  3.5362e-02,
#         -1.8649e-02, -4.2993e-02, -4.3470e-02, -1.1696e-01,  7.0979e-02,
#         -3.4023e-02,  6.7308e-02, -2.8952e-02,  6.5847e-02, -2.7334e-03,
#         -7.0532e-02, -1.8330e-02,  3.3860e-02, -2.8910e-02,  1.1927e-03,
#         -1.9366e-03,  2.6977e-02, -2.3719e-03, -1.0401e-02,  4.9077e-02,
#          2.4097e-02,  9.0913e-02, -1.7049e-02, -2.0641e-02, -2.0228e-02,
#          7.6418e-03,  3.0118e-02,  4.2432e-03, -4.6377e-02,  5.9423e-02,
#          3.1248e-02, -5.3434e-02,  1.5326e-01, -1.1810e-02, -4.1426e-03,
#          3.3999e-02,  2.2236e-03, -5.2555e-02,  2.4493e-02,  5.1567e-02,
#         -3.0323e-02,  6.7201e-02,  1.2256e-01, -5.5359e-33,  1.1253e-02,
#          6.3433e-02, -5.4464e-02,  9.8863e-03, -6.1594e-02,  1.2237e-02,
#          8.3626e-02,  1.4067e-02,  9.1464e-02,  4.7240e-02,  2.7721e-02,
#         -3.8492e-02,  5.1950e-02, -1.8772e-02,  4.6261e-02, -4.3545e-02,
#          4.5180e-02,  4.7118e-02, -4.7346e-02, -5.1169e-02, -1.0591e-01,
#          5.3593e-03, -5.8704e-03, -4.3645e-02, -1.0530e-02,  4.8202e-02,
#         -1.4325e-02,  3.4445e-02,  5.7187e-03,  2.2608e-02, -4.5591e-02,
#         -1.0367e-01, -7.4373e-02,  8.5257e-02, -3.5027e-02, -4.4268e-02,
#         -3.8807e-02,  9.3979e-02, -2.2301e-02, -1.2005e-02, -5.7963e-02,
#          3.9740e-02,  1.0267e-02,  7.8465e-02,  5.0005e-02, -3.6592e-02,
#          7.0051e-02,  2.0552e-02,  4.9360e-02, -5.1195e-02,  7.3113e-02,
#          6.0467e-02, -1.7450e-02,  1.7352e-02,  7.6142e-02,  5.8306e-02,
#          5.9806e-04, -4.9902e-03,  1.1216e-02, -5.7837e-02,  1.2642e-01,
#          1.6045e-02,  2.1244e-02,  5.6264e-02,  4.5880e-02,  3.2944e-03,
#          3.6053e-02, -7.7799e-03,  9.2169e-02, -8.2810e-02, -5.6468e-02,
#         -1.6598e-02,  4.8938e-02,  1.8401e-02,  7.5034e-03, -1.1608e-02,
#         -9.3922e-03,  2.0392e-01,  1.1924e-02,  9.4229e-02,  4.8656e-02,
#         -2.1660e-02, -1.0736e-01, -4.8307e-02,  3.9888e-03, -6.9713e-02,
#          1.5641e-02, -7.6658e-02,  9.8783e-03,  5.5671e-02, -1.1101e-01,
#         -1.3103e-02,  5.8554e-02,  8.9199e-02, -5.1428e-02, -1.9932e-08,
#         -2.2614e-02, -5.3130e-02, -5.4043e-02,  2.9701e-02,  9.4796e-02,
#          1.0289e-02, -7.5283e-02,  6.9121e-03, -1.0277e-01, -5.5365e-02,
#          8.7431e-02,  1.1553e-02, -4.3299e-02,  9.5166e-02, -6.9686e-02,
#         -5.7027e-02, -1.4657e-02,  2.2880e-02,  1.4802e-02, -3.8900e-02,
#          2.0995e-02, -1.3047e-02, -2.8258e-02,  5.0753e-02,  4.9723e-03,
#          2.3522e-02,  5.3011e-03,  4.0382e-02,  7.1550e-03, -6.6069e-02,
#          3.2808e-02, -5.9479e-02,  2.0603e-03, -1.0817e-02, -2.5810e-02,
#          5.0472e-02,  1.9754e-02,  8.5283e-02,  4.9463e-02,  1.1038e-01,
#         -1.7007e-02, -9.8099e-02, -8.3491e-03,  5.7634e-02,  4.7812e-02,
#          8.8170e-03, -7.4466e-02,  1.6901e-02, -5.9824e-02, -1.2116e-02,
#          4.1824e-02, -4.6291e-02,  1.6368e-02,  1.7031e-02, -1.8584e-03,
#         -4.8743e-02, -2.3558e-02, -5.1454e-02, -1.3599e-01, -2.4352e-04,
#         -2.5930e-02, -3.9354e-02,  6.9136e-03,  4.9543e-02])

# %% [markdown]
# # Save and Load Embeddings

# %%
import pickle

# Save the embeddings to a file
with open('embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings, f)

# %%
embeddings = pickle.load(open('embeddings.pkl', 'rb'))

# %% [markdown]
# # Step 6: Recommendations

# %%
# Function to recommend top N articles based on a search query
def recommend_articles_from_search(query, df, model, num_recommendations=5):
    # Step 0: Clean Query
    query = preprocess_text(query)
    # Step 1: Get the embedding for the search query
    query_embedding = model.encode(query, convert_to_tensor=True)

    # Step 2: Compute cosine similarity between the query and all article embeddings
    similarities = cosine_similarity(query_embedding.reshape(1, -1), embeddings)

    # Step 3: Get the indices of the top N most similar articles
    similarities = similarities.flatten()  # Flatten the 2D array to 1D
    top_indices = similarities.argsort()[-num_recommendations:][::-1]  # Get indices of top N

    # Step 4: Retrieve the corresponding articles and their similarity scores
    recommended_articles = df.iloc[top_indices][['Heading', 'NewsType', 'Article', 'Date']]
    return recommended_articles, similarities[top_indices]

# %%
# Example usage of the recommendation function
query = "Asian markets upswing"
recommended_articles, similarity_scores = recommend_articles_from_search(query, df, model, num_recommendations=5)

recommended_articles
# Out:
#                                                 Heading  NewsType  \
# 119          most asian markets up tokyo at 15 year hig  business
# 226    asian markets mostly recover from hefty sell off  business
# 2610        Dollar down Trump takes over Asia markets u  business
# 220   asia markets mostly down shanghai up a 7th str...  business
# 546   Asia stocks edge up to four month high after W...  business
#
#                                                 Article       Date
# 119   Hong Kong: Japanese shares hit a 15-year high ...  4/22/2015
# 226   Hong Kong: Most Asia shares rose Wednesday as ...  7/29/2015
# 2610  strong>HONG KONG: The dollar retreated against...  1/23/2017
# 220   Hong Kong: Asian markets mostly fell Friday fo...  7/24/2015
# 546   strong>TOKYO: Asian shares edged up to a four-...  3/31/2016

# %%
# Example usage of the recommendation function
query = "Karachi News"
recommended_articles, similarity_scores = recommend_articles_from_search(query, df, model, num_recommendations=5)

recommended_articles
# Out:
#                                                 Heading  NewsType  \
# 1230        Islamabad emerge victorious against Karachi    sports
# 1277      Karachi eliminated Islamabad to play Peshawar    sports
# 1175                Karachi restrict Islamabad to 132 8    sports
# 1280  PSL Islamabad thump Peshawar to face Quetta in fi    sports
# 723     Pakistans stock market dominates Asia Bloomberg  business
#
#                                                 Article       Date
# 1230  SHARJAH: Islamabad United defeated Karachi Kin...  2/14/2016
# 1277  DUBAI: Islamabad United defeated Karachi Kings...  2/21/2016
# 1175  DUBAI: Karachi Kings restricted to Islamabad U...   2/7/2016
# 1280  strong>DUBAI: Sharjeel Khans smashing 117 off...  2/22/2016
# 723   strong>ISLAMABAD: Asias best-performing stock...  6/15/2016
